# %%
sum_1000 = 0
for i in range(1, 1000, 1):
    if i%5 == 0 or i%3 == 0:
        sum_1000 += i

print(sum_1000)

# %% [markdown]
# # Crible_eratosthene
#
# pour décomposer un chiffre par des nombre premier

# %%
def crible_eratosthene(n):

    prime = [i for i in range(2,n+1,1)]
    a = 0
    for i in prime:
        if i*i <= n+1:
            for y in prime :
                a += 1
                if y!= i  and y%i == 0:
                    prime.remove(y)
    print(a)
    return prime

# %% [markdown]
# ## Exo 2 Even Fibonacci Numbers
#
# Each new term in the Fibonacci sequence is generated by adding the previous two terms. By starting with
# 1 and 2
# , the first 10
#  terms will be: 1,2,3,5,8,13,21,34,55,88
#
# By considering the terms in the Fibonacci sequence whose values do not exceed four million, find the sum of the even-valued terms.

# %%
terme_avant = 1
terme = 2
sum_even = 0

while terme <= 4_000_000:
    if terme % 2 == 0:
        sum_even += terme
    terme = terme + terme_avant
    terme_avant = terme - terme_avant


print(sum_even)

# %% [markdown]
# # Problem 3
# ## Largest Prime Factor
#
# The prime factors of 13195
#  are 5,7,13
#  and 29
#
# What is the largest prime factor of the number 600851475143
# ?

# %%
test = 600851475143

def prime_factors (n):
    prime = []
    while n % 2 == 0:
        prime.append(2)
        n //= 2
        
    for i in range(3,int(n**0.5)+1,2):
         while n % i == 0: 
            prime.append(i)
            n //= i             
    
    if n > 2:
        prime.append(n)
    return prime


print(prime_factors(test))

# %% [markdown]
# # Problem 4
# ## Largest Palindrome Product
#
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2
# -digit numbers is
# . 9009 = 91x99
#
# Find the largest palindrome made from the product of two 3-digit numbers.

# %%
three_most_number = 999*999
hight_number = 999
list_sum = []

for i in range (hight_number,0,-1):
    for y in range (hight_number,0,-1):
        num_sum = i*y
        if str(num_sum) == str(num_sum)[::-1]:
            list_sum.append(num_sum)
        
        
print(len(list_sum))        
print(max(list_sum))

# %% [markdown]
# # Problem 5
# ## Smallest Multiple
#
# wave of improvement GCD and LCM
#
#  2520 is the smallest number that can be divided by each of the numbers from
#  1 to 10
#  without any remainder.
#
# What is the smallest positive number that is evenly divisible by all of the numbers from
# 1 to 20
# ?

# %%
print(1*2*3*5*7*11*13*17*19)
232792560

# %%
counter = 1
for i in range(1,232792560,1):
    if i%2520 ==0 and i%11==0 and i%13 ==0 and i%17 ==0 and i%19==0 and i%20 ==0:
        print(i)
        break

# %%
i = 1
flag = False
while flag == False:
    if all(i%y ==0 for y in range(1,21)):
        flag = True
        print(i)
    i += 1

# %% [markdown]
# # PROJECT EULER
# #
#
# ## Ex1
# If we list all the natural numbers below 10 that are multiples of 3 or 5
# we get 3,5,6 and 9 The sum of these multiples is 23
#
# Find the sum of all the multiples of 3 or 5 below 1000

# %% [markdown]
# # Problem 6
#
# ## Sum Square Difference
#
# The sum of the squares of the first ten natural numbers is
#
#     1²+2²+...+10²=285
#
# The square of the sum of the first ten natural numbers is
#
#     (1+2+...+10)² = 55² = 3025
#
# Hence the difference between the sum of the squares of the first ten natural numbers and the square of the sum is
#
#     3025 - 385 = 2640
#
# Find the difference between the sum of the squares of the first one hundred numbers and the square of the sum

# %%
sum_squares=0
squares_sum =0
for i in range(1,101):
    sum_squares += i*i
    squares_sum += i
    
print(squares_sum*squares_sum - sum_squares)

# %% [markdown]
# # PROBLEM 7
#
# ## 10 001st prime
#
# By listing the first six prime numbers:
# 2 3 5 7 11 and 13
#  , we can see that the 6th prime is 13
# .
#
# What is the 10 001
# st prime number?

# %%
from math import sqrt

sqrt(4)

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# %%
i = 1
flag = False
prime_count =0

while prime_count < 10_001:
    if is_prime(i) :
        prime_count +=1
        print(i)
    i +=1

# %% [markdown]
# # Probleme 8
#
# ## Largest Product in a Series

# %%
nombre = ("73167176531330624919225119674426574742355349194934"
          "96983520312774506326239578318016984801869478851843"
          "85861560789112949495459501737958331952853208805511"
          "12540698747158523863050715693290963295227443043557"
          "66896648950445244523161731856403098711121722383113"
          "62229893423380308135336276614282806444486645238749"
          "30358907296290491560440772390713810515859307960866"
          "70172427121883998797908792274921901699720888093776"
          "65727333001053367881220235421809751254540594752243"
          "52584907711670556013604839586446706324415722155397"
          "53697817977846174064955149290862569321978468622482"
          "83972241375657056057490261407972968652414535100474"
          "82166370484403199890008895243450658541227588666881"
          "16427171479924442928230863465674813919123162824586"
          "17866458359124566529476545682848912883142607690042"
          "24219022671055626321111109370544217506941658960408"
          "07198403850962455444362981230987879927244284909188"
          "84580156166097919133875499200524063689912560717606"
          "05886116467109405077541002256983155200055935729725"
          "71636269561882670428252483600823257530420752963450")
max_solution = 0
nb_digit = 13
print(len((nombre)))
for i in range(len(nombre)-nb_digit+1):
    temps_solution = 1
    for y in range(0, nb_digit, 1):
        temps_solution *= int(nombre[i+y])
        # t = int(a[i])*int(a[i+1])*int(a[i+2])*int(a[i+3])
    if temps_solution > max_solution:
        max_solution = temps_solution

print(max_solution)

# %% [markdown]
# # PROBLEME 9
#
# ## Special Pythagorean Triplet

# %%
a = 1
b = 1
c = 1
for b in range (5,500,1):
    for a in range (3,b,1):
        if a+b+c ==1000 and a*a+b*b==c*c:
            print(a,b,c)

# %%
import random
from math import *

flag = True
while flag == True:

    b = random.randrange(5,500 + 1)
    a = random.randrange(3,b)
    c = sqrt(a*a+b*b)

    if a+b+c ==1000 and a*a+b*b==c*c:
        print(a,b,c)
        flag = False

# %% [markdown]
# # Probleme 10
#
# ## Summation of Primes
#
# he sum of the primes below
# 10 is 2+3+5+7 =17
#
#
# Find the sum of all the primes below two million.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

number = 1
sum_prime = 0
while number < 2_000_000:
    if is_prime(number) == True:
        sum_prime += number

    number += 1
print(sum_prime)

# %% [markdown]
# # Problem 11
#
# ## Largest Product in a Grid
#
# In the 20 x 20
#  grid below, four numbers along a diagonal line have been marked in red.

# %%
import numpy as np
import math

grid_str = ('''08 02 22 97 38 15 00 40 00 75 04 05 07 78 52 12 50 77 91 08 
          49 49 99 40 17 81 18 57 60 87 17 40 98 43 69 48 04 56 62 00 
          81 49 31 73 55 79 14 29 93 71 40 67 53 88 30 03 49 13 36 65 
          52 70 95 23 04 60 11 42 69 24 68 56 01 32 56 71 37 02 36 91 
          22 31 16 71 51 67 63 89 41 92 36 54 22 40 40 28 66 33 13 80 
          24 47 32 60 99 03 45 02 44 75 33 53 78 36 84 20 35 17 12 50 
          32 98 81 28 64 23 67 10 26 38 40 67 59 54 70 66 18 38 64 70 
          67 26 20 68 02 62 12 20 95 63 94 39 63 08 40 91 66 49 94 21 
          24 55 58 05 66 73 99 26 97 17 78 78 96 83 14 88 34 89 63 72 
          21 36 23 09 75 00 76 44 20 45 35 14 00 61 33 97 34 31 33 95 
          78 17 53 28 22 75 31 67 15 94 03 80 04 62 16 14 09 53 56 92 
          16 39 05 42 96 35 31 47 55 58 88 24 00 17 54 24 36 29 85 57 
          86 56 00 48 35 71 89 07 05 44 44 37 44 60 21 58 51 54 17 58 
          19 80 81 68 05 94 47 69 28 73 92 13 86 52 17 77 04 89 55 40 
          04 52 08 83 97 35 99 16 07 97 57 32 16 26 26 79 33 27 98 66 
          88 36 68 87 57 62 20 72 03 46 33 67 46 55 12 32 63 93 53 69 
          04 42 16 73 38 25 39 11 24 94 72 18 08 46 29 32 40 62 76 36 
          20 69 36 41 72 30 23 88 34 62 99 69 82 67 59 85 74 04 36 16
          20 73 35 29 78 31 90 01 74 31 49 71 48 86 81 16 23 57 05 54 
          01 70 54 71 83 51 54 69 16 92 33 48 61 43 52 01 89 19 67 48 ''')


matrice = [[int(num) for num in line.split()] for line in grid_str.strip().split('\n')]
def verife(local_max,max_multipe):

    if local_max > max_multipe:
        max_multipe = local_max

    return max_multipe

max_multipe = 0
local_multiple_vertical = 0
local_multiple_horizontal =0
diagonal_down_right =0
diagonal_down_left =0

# i est l'indice de la ligne
# y est l'indice de du nombre
# matrice [4][7] c'est la 8éme valeur de la ligne 5

for y in range(len(matrice)):
    for i in range(len(matrice)):

        #multiplication horizontale
        if y+3 < len(matrice):
            local_multiple_horizontal = matrice[i][y]*matrice[i][y+1]*matrice[i][y+2]*matrice[i][y+3]
            max_multipe = verife(local_multiple_horizontal,max_multipe)
            print('chiffre pour droit',matrice[i][y],matrice[i][y+1],matrice[i][y+2],matrice[i][y+3])

        # multiplication verticale
        if i+3 < len(matrice):
            local_multiple_vertical = matrice[i][y] * matrice[i + 1][y] * matrice[i + 2][y] * matrice[i + 3][y]
            max_multipe = verife(local_multiple_vertical, max_multipe)
            print ('chiffre pour le bas',matrice[i][y] , matrice[i + 1][y] , matrice[i + 2][y] , matrice[i + 3][y])

        # multiplication diagonale
        if i+3 < len(matrice) and y+3 < len(matrice):
            diagonal_down_right = matrice[i][y] * matrice[i+1][y + 1] * matrice[i+2][y + 2] * matrice[i+3][y + 3]
            max_multipe = verife(diagonal_down_right, max_multipe)
            print('chiffre pour la diagonale droite', matrice[i][y] , matrice[i+1][y + 1] , matrice[i+2][y + 2] , matrice[i+3][y + 3])

        # multiplication diagonale bas en haut
            diagonal_down_left = matrice[i+3][y] * matrice[i+2][y+1] * matrice[i+1][y+2] * matrice[i][y+3]
            max_multipe = verife(diagonal_down_left, max_multipe)
            print('chiffre pour la diagonale gauche', matrice[i+3][y] , matrice[i+2][y+1] , matrice[i +1 ][y+2] , matrice[i][y+3])

print(len(matrice))
print(max_multipe)

# %% [markdown]
# # Problem 12
#
# ## Highly Divisible Triangular Number

# %%
def crible_eratosthene(n):

    prime = [i for i in range(2,n+1,1)]
    a = 0
    for i in prime:
        if i*i <= n+1:
            for y in prime :
                a += 1
                if y!= i  and y%i == 0:
                    prime.remove(y)
    print(a)
    return prime

# tn désigne le n-ième nombre triangulaire :
tn = 0
nom_triangulaire = 1
while i == 5:
    tn +=1
    nom_triangulaire += nom_triangulaire +1
    crible_eratosthene(nom_triangulaire)
    print(nom_triangulaire)

# %%
a = 28
diviseur_n = []
nom_triangulaire = 1
while len(diviseur_n) <5:
    print(nom_triangulaire)
    nom_triangulaire = nom_triangulaire +2
    for i in range(2,nom_triangulaire,1):

# %%
y = 500
s=0
l =[]
while i != y :
    l.append(i)
    l.append(y)
    s += i * y
    y -=1
    if i ==y:
        print(i,y)
        
print(len(l))
print(s)

# %%
import math

def trouver_diviseurs(n):
    diviseurs = set()
    for i in range(1, int(math.sqrt(n)) + 1):
        if n % i == 0:
            diviseurs.add(i)
            diviseurs.add(n // i)
    return list(diviseurs)

#nombre a trouver:

flag = True
i = 1

while flag:
    i += 1
    nom_triangulaire = sum(i for i in range(1,i))
    
    if len(trouver_diviseurs(nom_triangulaire)) > 499:
        print(f"Nombre de diviseurs : {len(trouver_diviseurs(nom_triangulaire))}")
        print(f"Nombre triangulaire : {nom_triangulaire}")
        flag = False

# %% [markdown]
# # Problem 13
#
# ## Large Sum

# %%
num = '''37107287533902102798797998220837590246510135740250
46376937677490009712648124896970078050417018260538
74324986199524741059474233309513058123726617309629
91942213363574161572522430563301811072406154908250
23067588207539346171171980310421047513778063246676
89261670696623633820136378418383684178734361726757
28112879812849979408065481931592621691275889832738
44274228917432520321923589422876796487670272189318
47451445736001306439091167216856844588711603153276
70386486105843025439939619828917593665686757934951
62176457141856560629502157223196586755079324193331
64906352462741904929101432445813822663347944758178
92575867718337217661963751590579239728245598838407
58203565325359399008402633568948830189458628227828
80181199384826282014278194139940567587151170094390
35398664372827112653829987240784473053190104293586
86515506006295864861532075273371959191420517255829
71693888707715466499115593487603532921714970056938
54370070576826684624621495650076471787294438377604
53282654108756828443191190634694037855217779295145
36123272525000296071075082563815656710885258350721
45876576172410976447339110607218265236877223636045
17423706905851860660448207621209813287860733969412
81142660418086830619328460811191061556940512689692
51934325451728388641918047049293215058642563049483
62467221648435076201727918039944693004732956340691
15732444386908125794514089057706229429197107928209
55037687525678773091862540744969844508330393682126
18336384825330154686196124348767681297534375946515
80386287592878490201521685554828717201219257766954
78182833757993103614740356856449095527097864797581
16726320100436897842553539920931837441497806860984
48403098129077791799088218795327364475675590848030
87086987551392711854517078544161852424320693150332
59959406895756536782107074926966537676326235447210
69793950679652694742597709739166693763042633987085
41052684708299085211399427365734116182760315001271
65378607361501080857009149939512557028198746004375
35829035317434717326932123578154982629742552737307
94953759765105305946966067683156574377167401875275
88902802571733229619176668713819931811048770190271
25267680276078003013678680992525463401061632866526
36270218540497705585629946580636237993140746255962
24074486908231174977792365466257246923322810917141
91430288197103288597806669760892938638285025333403
34413065578016127815921815005561868836468420090470
23053081172816430487623791969842487255036638784583
11487696932154902810424020138335124462181441773470
63783299490636259666498587618221225225512486764533
67720186971698544312419572409913959008952310058822
95548255300263520781532296796249481641953868218774
76085327132285723110424803456124867697064507995236
37774242535411291684276865538926205024910326572967
23701913275725675285653248258265463092207058596522
29798860272258331913126375147341994889534765745501
18495701454879288984856827726077713721403798879715
38298203783031473527721580348144513491373226651381
34829543829199918180278916522431027392251122869539
40957953066405232632538044100059654939159879593635
29746152185502371307642255121183693803580388584903
41698116222072977186158236678424689157993532961922
62467957194401269043877107275048102390895523597457
23189706772547915061505504953922979530901129967519
86188088225875314529584099251203829009407770775672
11306739708304724483816533873502340845647058077308
82959174767140363198008187129011875491310547126581
97623331044818386269515456334926366572897563400500
42846280183517070527831839425882145521227251250327
55121603546981200581762165212827652751691296897789
32238195734329339946437501907836945765883352399886
75506164965184775180738168837861091527357929701337
62177842752192623401942399639168044983993173312731
32924185707147349566916674687634660915035914677504
99518671430235219628894890102423325116913619626622
73267460800591547471830798392868535206946944540724
76841822524674417161514036427982273348055556214818
97142617910342598647204516893989422179826088076852
87783646182799346313767754307809363333018982642090
10848802521674670883215120185883543223812876952786
71329612474782464538636993009049310363619763878039
62184073572399794223406235393808339651327408011116
66627891981488087797941876876144230030984490851411
60661826293682836764744779239180335110989069790714
85786944089552990653640447425576083659976645795096
66024396409905389607120198219976047599490197230297
64913982680032973156037120041377903785566085089252
16730939319872750275468906903707539413042652315011
94809377245048795150954100921645863754710598436791
78639167021187492431995700641917969777599028300699
15368713711936614952811305876380278410754449733078
40789923115535562561142322423255033685442488917353
44889911501440648020369068063960672322193204149535
41503128880339536053299340368006977710650566631954
81234880673210146739058568557934581403627822703280
82616570773948327592232845941706525094512325230608
22918802058777319719839450180888072429661980811197
77158542502016545090413245809786882778948721859617
72107838435069186155435662884062257473692284509516
20849603980134001723930671666823555245252804609722
53503534226472524250874054075591789781264330331690'''


list_all_num =[[num for num in line]for line in num.strip().split('\n')]
    
print('Le type de la liste est ',type(list_all_num[1]))
solution =0
s =""
for e in list_all_num:
    number_str = ''.join(e[0:20])
    number = int(number_str)
    solution += number
    
print(solution)

# %% [markdown]
# # Problem 14
#
# ## Longest Collatz Sequence
#
# the following iterative sequence is defined for the set of positive integers:
#
#  N -> n/2(N is even)
#
#  N -> 3N+1(N is odd)
#
# Using the rule above and starting with 13, we generate the following sequence:
#
# 13 -> 40 -> 20 -> 10 -> 5 -> 16 -> 8 -> 4 -> 2 -> 1
#
# It can be seen that this sequence (starting at 13 and finishing at 1) contains
# 10 terms. Although it has not been proved yet (Collatz Problem), it is thought that all starting numbers finish at 1
# .
#
# Which starting number, under one million, produces the longest chain?
#
# NOTE: Once the chain starts the terms are allowed to go above one million.

# %%
def collatz_sequence(n):
    conteur_deboucle = 0

    while n != 1:
        leng_sequence_collatz(n,conteur_deboucle)
        conteur_deboucle += 1
        if n % 2 == 0:
            n = n / 2
        else:
            n = 3 * n + 1

    memo[n] = conteur_deboucle
    return conteur_deboucle


memo = {}


def leng_sequence_collatz(n, conteur_deboucle):
    if n in memo.keys():
        return memo[n]+conteur_deboucle
    else:
        return False



len_most_long = 0
i=0
nombre_produisant_max_longueur = 0
for i in range(1, 1_000_000):
    leng_sequence = collatz_sequence(i)
    if leng_sequence > len_most_long:
        len_most_long = leng_sequence
        nombre_produisant_max_longueur = i
        
print(f"Le nombre inférieur à {1_000_000} qui produit la chaîne de Collatz la plus longue est : {nombre_produisant_max_longueur}")

# %% [markdown]
# # Problem 15
#
# ## Lattice Paths
#
# Starting in the top left corner of a 2*2
#  grid, and only being able to move to the right and down, there are exactly 6
#  routes to the bottom right corner.
#
# How many such route there through a 20*20 gird

# %%
from math import factorial
dim_boit=20

resulte = factorial(2*20)/(factorial(dim_boit)*factorial(dim_boit))
print(resulte)

# %% [markdown]
# # Probleme 16
#
# ## Power Digit Sum

# %%
digits_str = str(2**1_000)
digits_sum = 0
digits_str_list = list(digits_str)
for e in digits_str_list:
    digits_sum += int(e)
print(digits_sum)

# %% [markdown]
# # Probleme 17
#
# # Number Letter Counts
#
# If the numbers
#  1 to 5
#  are written out in words: one, two, three, four, five, then there are
#
# 3+3+5+4+4 =19
#
#  letters used in total.
#
# If all the numbers from
#  1 to 1000
#  (one thousand) inclusive were written out in words, how many letters would be used?

# %%
from num2words import num2words

number_in_words = ''

for number in range(1, 1001):
    number_in_words += num2words(number)

str_caratere_number =''
charatere_number_in_words = list(number_in_words)
for e in charatere_number_in_words:
    if ord('a') <= ord(e) <= ord('z'):
        str_caratere_number += e
print(len(str_caratere_number))

# %% [markdown]
# # Probleme 18
#
# ## Maximun Path Sum 1

# %%
triangle = ''' 
75
95 64
17 47 82
18 35 87 10
20 04 82 47 65
19 01 23 75 03 34
88 02 77 73 07 63 67
99 65 04 28 06 16 70 92
41 41 26 56 83 40 80 70 33
41 48 72 33 47 32 37 16 94 29
53 71 44 65 25 43 91 52 97 51 14
70 11 33 28 77 73 17 78 39 68 17 57
91 71 52 38 17 14 91 43 58 50 27 29 48
63 66 04 68 89 53 67 30 73 16 69 87 40 31
04 62 98 27 23 09 70 98 73 93 38 53 60 04 23'''

# Split the string into lines
triangle = triangle.split("\n")
triangle_list_de_list = []

# Process each line
for element in triangle:
    numbers = list(map(int, element.strip().split()))
    triangle_list_de_list.append(numbers)

# Print the processed list of lists

local_max_sum = [[0] * len(ligne) for ligne in triangle_list_de_list]
max_sum = 0

#logique de code
for i in range(len(triangle_list_de_list)):
    for y in range(len(triangle_list_de_list[i])):
        if local_max_sum[i][y] < triangle_list_de_list[i][y] + (local_max_sum[i-1][y] if i > 0 and y < len(local_max_sum[i-1]) else 0):
            right_parent = (local_max_sum[i-1][y] if i > 0 and y < len(local_max_sum[i-1]) else 0)
            left_parent = local_max_sum[i-1][y-1] if y-1 >= 0 else 0
            local_max_sum[i][y] = triangle_list_de_list[i][y] + max(right_parent,left_parent)


print(local_max_sum[-1])

#local_max_sum = triangle_list_de_list[0][0]+triangle_list_de_list[1][0]+triangle_list_de_list[2][0]+triangle_list_de_list[3][0]
print(max_sum)

# %% [markdown]
# # Problem 19
#
# ## Counting Sundays
#
#
# You are given the following information, but you may prefer to do some research for yourself.
#
# 1 Jan 1900 was a Monday.
# Thirty days has September,
# April, June and November.
# All the rest have thirty-one,
# Saving February alone,
# Which has twenty-eight, rain or shine.
# And on leap years, twenty-nine.
# A leap year occurs on any year evenly divisible by 4, but not on a century unless it is divisible by 400.
# How many Sundays fell on the first of the month during the twentieth century (1 Jan 1901 to 31 Dec 2000)?

# %%
nmbr_dimanche_1_jour_mois = 0
mois_jour = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
jour_nom = ['mardi', 'mercredi', 'jeudi', 'vendre', 'samedi', 'dimanche', 'lundi']
jour_actuelle = ''
jour_total =0

def annee_bissextile(anne):
    if anne % 4 == 0 and annee % 100 != 0 or annee % 400 == 0:
        return True


for annee in range(1901, 2000, 1):
    mois_jour[1] = 28
    nmbr_jour = 0
    print('on est en ', annee)
    if annee_bissextile(annee):
        mois_jour[1] = 29
    for mois in range(0, 12):
        for jour in range(mois_jour[mois]):
            print('nous somme le jour', jour_actuelle, 'de l anne', annee)
            nmbr_jour += 1

            jour_actuelle = jour_nom[jour_total % 7]
            jour_total +=1
        if jour_actuelle == 'dimanche':
            nmbr_dimanche_1_jour_mois += 1
    print(nmbr_dimanche_1_jour_mois)

# %%
n = 1
for i in range(1, 101, 1):
    n *= i

list_chiffre = [int(chiffre) for chiffre in str(n)]
solution = 0
for e in list_chiffre:
    solution += e
print(solution)
